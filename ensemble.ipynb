# %%
import pandas as pd
import numpy as np
import os

# %%
#Avg
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Define the path to the records folder
records_path = "./records"

# List to store DataFrames
dataframes = []

# Read all CSVs in the folder and combine them
for file in os.listdir(records_path):
    if file.endswith(".csv"):
        if "Test" in file:
            filepath = os.path.join(records_path, file)
            df = pd.read_csv(filepath)
            print(filepath)
            dataframes.append(df)

# Concatenate all dataframes
combined_df = pd.concat(dataframes, ignore_index=True)

# Ensure columns 'y_true' and 'y_predict' exist
if 'y_true' in combined_df.columns and 'y_predict' in combined_df.columns:
    # Group by y_true and average y_predict
    averaged_predictions = combined_df.groupby('y_true')['y_predict'].mean().reset_index()
    y_true = averaged_predictions['y_true']
    y_predict_avg = averaged_predictions['y_predict']
    
    # Calculate MAE and RMSE
    mae = mean_absolute_error(y_true, y_predict_avg)
    rmse = np.sqrt(mean_squared_error(y_true, y_predict_avg))
    
    # Print results
    print(f"Mean Absolute Error (MAE): {mae}")
    print(f"Root Mean Squared Error (RMSE): {rmse}")
else:
    print("The required columns ('y_true', 'y_predict') are not present in the CSV files.")
# Out:
# C:\Users\user\anaconda3\envs\STLF2\lib\site-packages\scipy\__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.26.4
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# ./records\Test_01-10_12_10.csv
# ./records\Test_01-10_12_16.csv
# ./records\Test_01-10_12_22.csv
# ./records\Test_01-11_11_31.csv
# ./records\Test_01-11_11_36.csv
# ./records\Test_01-11_11_48.csv
# ./records\Test_01-11_11_57.csv
# ./records\Test_01-11_12_10.csv
# ./records\Test_01-11_12_19.csv
# ./records\Test_01-11_12_30.csv
# ./records\Test_01-11_12_41.csv
# ./records\Test_01-11_12_48.csv
# ./records\Test_01-11_12_54.csv
# ./records\Test_01-11_15_50.csv
# ./records\Test_01-11_16_11.csv
# ./records\Test_01-11_16_20.csv
# ./records\Test_01-11_16_33.csv
# ./records\Test_01-11_16_41.csv
# ./records\Test_01-11_16_59.csv
# ./records\Test_01-11_17_13.csv
# ./records\Test_01-11_17_24.csv
# ./records\Test_01-12_13_02.csv
# ...

# %%
# Define the path to the records folder
records_path = "./records"

# List to store DataFrames
dataframes = []

# Read all CSVs in the folder and combine them
for file in os.listdir(records_path):
    if file.endswith(".csv"):
        if "Train" in file:
            filepath = os.path.join(records_path, file)
            df = pd.read_csv(filepath)
            print(filepath)
            dataframes.append(df)

combined_df_train = pd.concat(dataframes, ignore_index=True)
combined_df_train
# Out:
# ./records\Train_01-10_12_10.csv
# ./records\Train_01-10_12_16.csv
# ./records\Train_01-10_12_22.csv
# ./records\Train_01-11_11_31.csv
# ./records\Train_01-11_11_36.csv
# ./records\Train_01-11_11_48.csv
# ./records\Train_1.csv
# ./records\Train_10.csv
# ./records\Train_2.csv
# ./records\Train_3.csv
# ./records\Train_4.csv
# ./records\Train_5.csv
# ./records\Train_6.csv
# ./records\Train_7.csv
# ./records\Train_8.csv
# ./records\Train_9.csv
#             y_true  y_predict
# 0       142.767833  119.50885
# 1       117.386000  119.50885
# 2       118.581667  119.50885
# 3       120.378000  119.50885
# 4       123.815667  119.50885
# ...            ...        ...
# 161179  132.354500  128.46434
# 161180  127.327333  140.54768
# 161181  120.566000  129.64806
# 161182  138.925167  124.44624
# 161183  136.671333  137.25020
#
# [161184 rows x 2 columns]
